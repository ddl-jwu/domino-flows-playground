# %%
from flytekit.remote.remote import FlyteRemote
from flytekit.configuration import Config
remote = FlyteRemote(
    Config.auto(),
)
output = remote.get("flyte://v1/66abd0c2b1eb620ae16f2534/development/commonly-together-camel-5201/n0/o")

# %%
output
# Out:
# {'processed_data': 's3://flows-dev-flyte-data//261e4111-f7f7-445e-b5ea-fbdca60b911c/processed_data'}

# %%
from flytekit.types.file import FlyteFile
from typing import TypeVar

file = output.get('processed_data', FlyteFile[TypeVar('csv')])

# %%
file
# Out:
# /tmp/flyte-st45rw9b/sandbox/local_flytekit/8154fa73158cfbc4fba08a0ca8e2b014/processed_data

# %%
import pandas as pd

df = pd.read_csv(file)
# Out:
# ╭─────────────────────────────────────── Traceback (most recent call last) ───────────────────────────────────────╮
# │ /opt/conda/lib/python3.10/site-packages/flytekit/core/data_persistence.py:527 in get_data                       │
# │                                                                                                                 │
# │ ❱ 527 │   │   │   │   self.get(remote_path, to_path=local_path, recursive=is_multipart, **kwar                  │
# │                                                                                                                 │
# │ /opt/conda/lib/python3.10/site-packages/decorator.py:232 in fun                                                 │
# │                                                                                                                 │
# │ ❱ 232 │   │   │   return caller(func, *(extras + args), **kw)                                                   │
# │                                                                                                                 │
# │ /opt/conda/lib/python3.10/site-packages/flytekit/core/data_persistence.py:122 in retry_request                  │
# │                                                                                                                 │
# │ ❱ 122 │   │   │   │   raise e                                                                                   │
# │                                                                                                                 │
# │ /opt/conda/lib/python3.10/site-packages/flytekit/core/data_persistence.py:115 in retry_request                  │
# │                                                                                                                 │
# │ ❱ 115 │   │   │   return func(*args, **kwargs)                                                                  │
# │                                                                                                                 │
# │ /opt/conda/lib/python3.10/site-packages/flytekit/core/data_persistence.py:296 in get                            │
# │                                                                                                                 │
# │ ❱ 296 │   │   │   dst = file_system.get(from_path, to_path, recursive=recursive, **kwargs)                      │
# │                                                                                                                 │
# │ /opt/conda/lib/python3.10/site-packages/fsspec/asyn.py:118 in wrapper                                           │
# │                                                                                                                 │
# │ ❱  118 │   │   return sync(self.loop, func, *args, **kwargs)                                                    │
# │                                                                                                                 │
# │ /opt/conda/lib/python3.10/site-packages/fsspec/asyn.py:103 in sync                                              │
# │                                                                                                                 │
# │ ❱  103 │   │   raise return_result                                                                              │
# │                                                                                                                 │
# │ /opt/conda/lib/python3.10/site-packages/fsspec/asyn.py:56 in _runner                                            │
# │                                                                                                                 │
# │ ❱   56 │   │   result[0] = await coro                                                                           │
# │                                                                                                                 │
# │ /opt/conda/lib/python3.10/site-packages/fsspec/asyn.py:634 in _get                                              │
# │                                                                                                                 │
# │ ❱  634 │   │   │   │   rpaths = [                                                                               │
# │                                                                                                                 │
# │ /opt/conda/lib/python3.10/site-packages/fsspec/asyn.py:635 in <listcomp>                                        │
# │                                                                                                                 │
# │ ❱  635 │   │   │   │   │   p for p in rpaths if not (trailing_sep(p) or await self._isdir(p))                   │
# │                                                                                                                 │
# │ /opt/conda/lib/python3.10/site-packages/s3fs/core.py:1483 in _isdir                                             │
# │                                                                                                                 │
# │ ❱ 1483 │   │   │   return bool(await self._lsdir(path))                                                         │
# │                                                                                                                 │
# │ /opt/conda/lib/python3.10/site-packages/s3fs/core.py:723 in _lsdir                                              │
# │                                                                                                                 │
# │ ❱  723 │   │   │   │   async for c in self._iterdir(                                                            │
# │                                                                                                                 │
# │ /opt/conda/lib/python3.10/site-packages/s3fs/core.py:755 in _iterdir                                            │
# │                                                                                                                 │
# │ ❱  755 │   │   s3 = await self.get_s3(bucket)                                                                   │
# │                                                                                                                 │
# │ /opt/conda/lib/python3.10/site-packages/s3fs/core.py:353 in get_s3                                              │
# │                                                                                                                 │
# │ ❱  353 │   │   │   return await self._s3creator.get_bucket_client(bucket)                                       │
# │                                                                                                                 │
# │ /opt/conda/lib/python3.10/site-packages/s3fs/utils.py:39 in get_bucket_client                                   │
# │                                                                                                                 │
# │ ❱  39 │   │   │   response = await general_client.head_bucket(Bucket=bucket_name)                               │
# │                                                                                                                 │
# │ /opt/conda/lib/python3.10/site-packages/aiobotocore/client.py:391 in _make_api_call                             │
# │                                                                                                                 │
# │ ❱ 391 │   │   │   http, parsed_response = await self._make_request(                                             │
# │                                                                                                                 │
# │ /opt/conda/lib/python3.10/site-packages/aiobotocore/client.py:419 in _make_request                              │
# │                                                                                                                 │
# │ ❱ 419 │   │   │   return await self._endpoint.make_request(                                                     │
# │                                                                                                                 │
# │ /opt/conda/lib/python3.10/site-packages/aiobotocore/endpoint.py:98 in _send_request                             │
# │                                                                                                                 │
# │ ❱  98 │   │   request = await self.create_request(request_dict, operation_model)                                │
# │                                                                                                                 │
# │ /opt/conda/lib/python3.10/site-packages/aiobotocore/endpoint.py:86 in create_request                            │
# │                                                                                                                 │
# │ ❱  86 │   │   │   await self._event_emitter.emit(                                                               │
# │                                                                                                                 │
# │ /opt/conda/lib/python3.10/site-packages/aiobotocore/hooks.py:66 in _emit                                        │
# │                                                                                                                 │
# │ ❱ 66 │   │   │   response = await resolve_awaitable(handler(**kwargs))                                          │
# │                                                                                                                 │
# │ /opt/conda/lib/python3.10/site-packages/aiobotocore/_helpers.py:15 in resolve_awaitable                         │
# │                                                                                                                 │
# │ ❱ 15 │   │   return await obj                                                                                   │
# │                                                                                                                 │
# │ /opt/conda/lib/python3.10/site-packages/aiobotocore/signers.py:24 in handler                                    │
# │                                                                                                                 │
# │ ❱  24 │   │   return await self.sign(operation_name, request)                                                   │
# │                                                                                                                 │
# │ /opt/conda/lib/python3.10/site-packages/aiobotocore/signers.py:92 in sign                                       │
# │                                                                                                                 │
# │ ❱  92 │   │   │   auth.add_auth(request)                                                                        │
# │                                                                                                                 │
# │ /opt/conda/lib/python3.10/site-packages/botocore/auth.py:418 in add_auth                                        │
# │                                                                                                                 │
# │ ❱  418 │   │   │   raise NoCredentialsError()                                                                   │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# NoCredentialsError: Unable to locate credentials
#
# During handling of the above exception, another exception occurred:
#
# ╭─────────────────────────────────────── Traceback (most recent call last) ───────────────────────────────────────╮
# │ in <module>:3                                                                                                   │
# │                                                                                                                 │
# │ ❱ 3 df = pd.read_csv(file)                                                                                      │
# │                                                                                                                 │
# │ /opt/conda/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1026 in read_csv                           │
# │                                                                                                                 │
# │ ❱ 1026 │   return _read(filepath_or_buffer, kwds)                                                               │
# │                                                                                                                 │
# │ /opt/conda/lib/python3.10/site-packages/pandas/io/parsers/readers.py:620 in _read                               │
# │                                                                                                                 │
# │ ❱  620 │   parser = TextFileReader(filepath_or_buffer, **kwds)                                                  │
# │                                                                                                                 │
# │ /opt/conda/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1620 in __init__                           │
# │                                                                                                                 │
# │ ❱ 1620 │   │   self._engine = self._make_engine(f, self.engine)                                                 │
# │                                                                                                                 │
# │ /opt/conda/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1880 in _make_engine                       │
# │                                                                                                                 │
# │ ❱ 1880 │   │   │   self.handles = get_handle(                                                                   │
# │                                                                                                                 │
# │ /opt/conda/lib/python3.10/site-packages/pandas/io/common.py:728 in get_handle                                   │
# │                                                                                                                 │
# │ ❱  728 │   ioargs = _get_filepath_or_buffer(                                                                    │
# │                                                                                                                 │
# │ /opt/conda/lib/python3.10/site-packages/pandas/io/common.py:335 in _get_filepath_or_buffer                      │
# │                                                                                                                 │
# │ ❱  335 │   filepath_or_buffer = stringify_path(filepath_or_buffer)                                              │
# │                                                                                                                 │
# │ /opt/conda/lib/python3.10/site-packages/pandas/io/common.py:278 in stringify_path                               │
# │                                                                                                                 │
# │ ❱  278 │   │   filepath_or_buffer = filepath_or_buffer.__fspath__()                                             │
# │                                                                                                                 │
# │ /opt/conda/lib/python3.10/site-packages/flytekit/types/file/file.py:226 in __fspath__                           │
# │                                                                                                                 │
# │ ❱ 226 │   │   │   self._downloader()                                                                            │
# │                                                                                                                 │
# │ /opt/conda/lib/python3.10/site-packages/flytekit/types/file/file.py:525 in _downloader                          │
# │                                                                                                                 │
# │ ❱ 525 │   │   │   return ctx.file_access.get_data(uri, local_path, is_multipart=False)                          │
# │                                                                                                                 │
# │ /opt/conda/lib/python3.10/site-packages/flytekit/core/data_persistence.py:529 in get_data                       │
# │                                                                                                                 │
# │ ❱ 529 │   │   │   raise FlyteAssertion(                                                                         │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# FlyteAssertion: USER:AssertionError: error=Failed to get data from
# s3://flows-dev-flyte-data//261e4111-f7f7-445e-b5ea-fbdca60b911c/processed_data to
# /tmp/flyte-st45rw9b/sandbox/local_flytekit/8154fa73158cfbc4fba08a0ca8e2b014/processed_data (recursive=False).
#
# Original exception: Unable to locate credentials
