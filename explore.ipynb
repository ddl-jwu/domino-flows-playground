# %%
from flytekit.remote.remote import FlyteRemote
from flytekit.configuration import Config
remote = FlyteRemote(
    Config.for_endpoint("flows-demo37381.train-sandbox.domino.tech/flows"),
)
remote.get("flyte://v1/6615af2020a4dc035aa881b1/development/truly-blessed-airedale-3g8b/n0/o")
# Out:
# ╭─────────────────────────────────────── Traceback (most recent call last) ───────────────────────────────────────╮
# │ /opt/conda/lib/python3.10/site-packages/grpc/_interceptor.py:315 in continuation                                │
# │                                                                                                                 │
# │ ❱ 315 │   │   │   │   response, call = self._thunk(new_method).with_call(                                       │
# │                                                                                                                 │
# │ /opt/conda/lib/python3.10/site-packages/grpc/_interceptor.py:343 in with_call                                   │
# │                                                                                                                 │
# │ ❱ 343 │   │   return self._with_call(                                                                           │
# ...
